# %%
from oggm import utils, workflow, tasks, DEFAULT_BASE_URL, cfg
import yaml
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Vatnajökull rgi_ids

# %%
fp_rgi_ids = "/home/www/dtcg/test_files/case_study_regions/iceland/vatnajokull_rgi_ids.yml"
with open(fp_rgi_ids, 'r') as yaml_file:
    rgi_ids = yaml.safe_load(yaml_file)['rgi_ids']

# %% [markdown]
# # get preprocessed data of OGGM

# %%
cfg.initialize()
working_dir = 'working_dir'
utils.mkdir(working_dir)
cfg.PATHS['working_dir'] = working_dir

gdirs = workflow.init_glacier_directories(
    rgi_ids,  # which glaciers?
    prepro_base_url=DEFAULT_BASE_URL,  # where to fetch the data?
    from_prepro_level=4,  # what kind of data? 
    prepro_border=80  # how big of a map?
)
# Out:
# 2025-01-29 13:33:22: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2025-01-29 13:33:22: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2025-01-29 13:33:22: oggm.cfg: Multiprocessing: using all available processors (N=32)
# 2025-01-29 13:33:24: oggm.workflow: init_glacier_directories from prepro level 4 on 118 glaciers.
# 2025-01-29 13:33:24: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 118 glaciers
# 2025-01-29 13:33:24: oggm.workflow: WARNING: you are trying to run an entity task on 118 glaciers with multiprocessing turned off. OGGM will run faster with multiprocessing turned on.

# %% [markdown]
# # Elevation change comparison

# %% [markdown]
# ## Redo run for getting monthly output and load data

# %%
cfg.PARAMS['continue_on_error'] = True
workflow.execute_entity_task(tasks.run_from_climate_data, gdirs,
                             init_model_filesuffix='_spinup_historical',
                             init_model_yr=1979,
                             store_monthly_step=True,
                             ys=1979, ye=2020,
                             mb_elev_feedback='monthly',
                             output_filesuffix='_spinup_historical_monthly')

ds_monthly =  utils.compile_run_output(gdirs, input_filesuffix='_spinup_historical_monthly')
# Out:
# 2025-01-29 14:10:22: oggm.workflow: Execute entity tasks [run_from_climate_data] on 118 glaciers
# 2025-01-29 14:10:22: oggm.workflow: WARNING: you are trying to run an entity task on 118 glaciers with multiprocessing turned off. OGGM will run faster with multiprocessing turned on.
# 2025-01-29 14:10:22: oggm.core.flowline: (RGI60-06.00372) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:22: oggm.core.flowline: (RGI60-06.00372) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:22: oggm.core.flowline: (RGI60-06.00373) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:22: oggm.core.flowline: (RGI60-06.00373) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:23: oggm.core.flowline: (RGI60-06.00374) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:23: oggm.core.flowline: (RGI60-06.00374) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:23: oggm.core.flowline: (RGI60-06.00377) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:23: oggm.core.flowline: (RGI60-06.00377) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:23: oggm.core.flowline: (RGI60-06.00378) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:23: oggm.core.flowline: (RGI60-06.00378) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:24: oggm.core.flowline: (RGI60-06.00379) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:24: oggm.core.flowline: (RGI60-06.00379) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:24: oggm.core.flowline: (RGI60-06.00380) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:24: oggm.core.flowline: (RGI60-06.00380) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:25: oggm.core.flowline: (RGI60-06.00381) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:25: oggm.core.flowline: (RGI60-06.00381) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:25: oggm.core.flowline: (RGI60-06.00382) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:25: oggm.core.flowline: (RGI60-06.00382) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:25: oggm.core.flowline: (RGI60-06.00383) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:25: oggm.core.flowline: (RGI60-06.00383) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:26: oggm.core.flowline: (RGI60-06.00384) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:26: oggm.core.flowline: (RGI60-06.00384) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:26: oggm.core.flowline: (RGI60-06.00385) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:26: oggm.core.flowline: (RGI60-06.00385) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:27: oggm.core.flowline: (RGI60-06.00386) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:27: oggm.core.flowline: (RGI60-06.00386) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:27: oggm.core.flowline: (RGI60-06.00387) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:27: oggm.core.flowline: AttributeError occurred during task run_from_climate_data_spinup_historical_monthly on RGI60-06.00387: 'Dataset' object has no attribute 'time'
# 2025-01-29 14:10:27: oggm.core.flowline: (RGI60-06.00388) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:27: oggm.core.flowline: (RGI60-06.00388) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:27: oggm.core.flowline: (RGI60-06.00389) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:27: oggm.core.flowline: (RGI60-06.00389) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:28: oggm.core.flowline: (RGI60-06.00390) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:28: oggm.core.flowline: (RGI60-06.00390) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:28: oggm.core.flowline: (RGI60-06.00391) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:28: oggm.core.flowline: (RGI60-06.00391) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:29: oggm.core.flowline: (RGI60-06.00392) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:29: oggm.core.flowline: (RGI60-06.00392) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:29: oggm.core.flowline: (RGI60-06.00393) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:29: oggm.core.flowline: (RGI60-06.00393) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:29: oggm.core.flowline: (RGI60-06.00394) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:29: oggm.core.flowline: (RGI60-06.00394) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:30: oggm.core.flowline: (RGI60-06.00395) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:30: oggm.core.flowline: (RGI60-06.00395) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:30: oggm.core.flowline: (RGI60-06.00396) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:30: oggm.core.flowline: (RGI60-06.00396) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:31: oggm.core.flowline: (RGI60-06.00397) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:31: oggm.core.flowline: (RGI60-06.00397) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:31: oggm.core.flowline: (RGI60-06.00398) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:31: oggm.core.flowline: (RGI60-06.00398) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:31: oggm.core.flowline: (RGI60-06.00399) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:31: oggm.core.flowline: (RGI60-06.00399) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:32: oggm.core.flowline: (RGI60-06.00400) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:32: oggm.core.flowline: (RGI60-06.00400) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:32: oggm.core.flowline: (RGI60-06.00401) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:32: oggm.core.flowline: (RGI60-06.00401) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:33: oggm.core.flowline: (RGI60-06.00402) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:33: oggm.core.flowline: (RGI60-06.00402) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:33: oggm.core.flowline: (RGI60-06.00403) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:33: oggm.core.flowline: (RGI60-06.00403) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:33: oggm.core.flowline: (RGI60-06.00404) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:33: oggm.core.flowline: (RGI60-06.00404) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:34: oggm.core.flowline: (RGI60-06.00405) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:34: oggm.core.flowline: (RGI60-06.00405) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:34: oggm.core.flowline: (RGI60-06.00406) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:34: oggm.core.flowline: (RGI60-06.00406) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:35: oggm.core.flowline: (RGI60-06.00407) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:35: oggm.core.flowline: (RGI60-06.00407) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:35: oggm.core.flowline: (RGI60-06.00408) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:35: oggm.core.flowline: (RGI60-06.00408) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:35: oggm.core.flowline: (RGI60-06.00409) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:36: oggm.core.flowline: (RGI60-06.00409) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:36: oggm.core.flowline: (RGI60-06.00410) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:36: oggm.core.flowline: (RGI60-06.00410) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:36: oggm.core.flowline: (RGI60-06.00411) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:36: oggm.core.flowline: (RGI60-06.00411) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:37: oggm.core.flowline: (RGI60-06.00412) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:37: oggm.core.flowline: (RGI60-06.00412) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:37: oggm.core.flowline: (RGI60-06.00413) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:37: oggm.core.flowline: (RGI60-06.00413) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:38: oggm.core.flowline: (RGI60-06.00414) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:38: oggm.core.flowline: (RGI60-06.00414) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:38: oggm.core.flowline: (RGI60-06.00415) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:38: oggm.core.flowline: (RGI60-06.00415) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:39: oggm.core.flowline: (RGI60-06.00416) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:39: oggm.core.flowline: (RGI60-06.00416) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:39: oggm.core.flowline: (RGI60-06.00417) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:39: oggm.core.flowline: (RGI60-06.00417) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:40: oggm.core.flowline: (RGI60-06.00418) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:40: oggm.core.flowline: (RGI60-06.00418) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:40: oggm.core.flowline: (RGI60-06.00419) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:40: oggm.core.flowline: (RGI60-06.00419) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:40: oggm.core.flowline: (RGI60-06.00420) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:40: oggm.core.flowline: (RGI60-06.00420) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:41: oggm.core.flowline: (RGI60-06.00421) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:41: oggm.core.flowline: (RGI60-06.00421) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:41: oggm.core.flowline: (RGI60-06.00422) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:41: oggm.core.flowline: (RGI60-06.00422) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:42: oggm.core.flowline: (RGI60-06.00423) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:42: oggm.core.flowline: (RGI60-06.00423) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:42: oggm.core.flowline: (RGI60-06.00424) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:42: oggm.core.flowline: (RGI60-06.00424) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:43: oggm.core.flowline: (RGI60-06.00425) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:43: oggm.core.flowline: (RGI60-06.00425) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:43: oggm.core.flowline: (RGI60-06.00426) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:43: oggm.core.flowline: (RGI60-06.00426) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:44: oggm.core.flowline: (RGI60-06.00427) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:44: oggm.core.flowline: (RGI60-06.00427) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:44: oggm.core.flowline: (RGI60-06.00428) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:44: oggm.core.flowline: (RGI60-06.00428) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:44: oggm.core.flowline: (RGI60-06.00429) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:44: oggm.core.flowline: (RGI60-06.00429) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:45: oggm.core.flowline: (RGI60-06.00430) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:45: oggm.core.flowline: (RGI60-06.00430) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:45: oggm.core.flowline: (RGI60-06.00431) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:45: oggm.core.flowline: (RGI60-06.00431) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:46: oggm.core.flowline: (RGI60-06.00432) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:46: oggm.core.flowline: (RGI60-06.00432) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:46: oggm.core.flowline: (RGI60-06.00433) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:46: oggm.core.flowline: (RGI60-06.00433) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:46: oggm.core.flowline: (RGI60-06.00434) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:46: oggm.core.flowline: (RGI60-06.00434) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:47: oggm.core.flowline: (RGI60-06.00435) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:47: oggm.core.flowline: (RGI60-06.00435) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:47: oggm.core.flowline: (RGI60-06.00436) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:47: oggm.core.flowline: (RGI60-06.00436) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:48: oggm.core.flowline: (RGI60-06.00437) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:48: oggm.core.flowline: (RGI60-06.00437) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:48: oggm.core.flowline: (RGI60-06.00438) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:48: oggm.core.flowline: (RGI60-06.00438) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:48: oggm.core.flowline: (RGI60-06.00439) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:48: oggm.core.flowline: (RGI60-06.00439) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:49: oggm.core.flowline: (RGI60-06.00440) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:49: oggm.core.flowline: (RGI60-06.00440) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:49: oggm.core.flowline: (RGI60-06.00441) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:49: oggm.core.flowline: (RGI60-06.00441) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:50: oggm.core.flowline: (RGI60-06.00442) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:50: oggm.core.flowline: (RGI60-06.00442) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:50: oggm.core.flowline: (RGI60-06.00443) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:50: oggm.core.flowline: (RGI60-06.00443) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:50: oggm.core.flowline: (RGI60-06.00444) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:50: oggm.core.flowline: (RGI60-06.00444) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:51: oggm.core.flowline: (RGI60-06.00445) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:51: oggm.core.flowline: (RGI60-06.00445) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:51: oggm.core.flowline: (RGI60-06.00446) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:51: oggm.core.flowline: (RGI60-06.00446) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:52: oggm.core.flowline: (RGI60-06.00447) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:52: oggm.core.flowline: (RGI60-06.00447) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:52: oggm.core.flowline: (RGI60-06.00448) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:52: oggm.core.flowline: (RGI60-06.00448) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:52: oggm.core.flowline: (RGI60-06.00449) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:52: oggm.core.flowline: (RGI60-06.00449) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:53: oggm.core.flowline: (RGI60-06.00450) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:53: oggm.core.flowline: (RGI60-06.00450) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:53: oggm.core.flowline: (RGI60-06.00451) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:53: oggm.core.flowline: (RGI60-06.00451) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:54: oggm.core.flowline: (RGI60-06.00452) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:54: oggm.core.flowline: (RGI60-06.00452) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:54: oggm.core.flowline: (RGI60-06.00453) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:54: oggm.core.flowline: (RGI60-06.00453) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:54: oggm.core.flowline: (RGI60-06.00454) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:55: oggm.core.flowline: (RGI60-06.00454) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:55: oggm.core.flowline: (RGI60-06.00455) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:55: oggm.core.flowline: (RGI60-06.00455) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:55: oggm.core.flowline: (RGI60-06.00456) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:55: oggm.core.flowline: (RGI60-06.00456) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:56: oggm.core.flowline: (RGI60-06.00457) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:56: oggm.core.flowline: (RGI60-06.00457) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:56: oggm.core.flowline: (RGI60-06.00458) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:56: oggm.core.flowline: (RGI60-06.00458) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:57: oggm.core.flowline: (RGI60-06.00459) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:57: oggm.core.flowline: (RGI60-06.00459) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:57: oggm.core.flowline: (RGI60-06.00460) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:57: oggm.core.flowline: (RGI60-06.00460) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:57: oggm.core.flowline: (RGI60-06.00461) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:57: oggm.core.flowline: (RGI60-06.00461) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:58: oggm.core.flowline: (RGI60-06.00462) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:58: oggm.core.flowline: (RGI60-06.00462) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:58: oggm.core.flowline: (RGI60-06.00463) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:58: oggm.core.flowline: (RGI60-06.00463) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:59: oggm.core.flowline: (RGI60-06.00464) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:59: oggm.core.flowline: (RGI60-06.00464) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:59: oggm.core.flowline: (RGI60-06.00465) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:59: oggm.core.flowline: (RGI60-06.00465) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:10:59: oggm.core.flowline: (RGI60-06.00466) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:10:59: oggm.core.flowline: (RGI60-06.00466) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:00: oggm.core.flowline: (RGI60-06.00467) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:00: oggm.core.flowline: (RGI60-06.00467) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:00: oggm.core.flowline: (RGI60-06.00468) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:00: oggm.core.flowline: (RGI60-06.00468) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:01: oggm.core.flowline: (RGI60-06.00469) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:01: oggm.core.flowline: (RGI60-06.00469) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:01: oggm.core.flowline: (RGI60-06.00470) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:01: oggm.core.flowline: (RGI60-06.00470) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:02: oggm.core.flowline: (RGI60-06.00471) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:02: oggm.core.flowline: (RGI60-06.00471) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:02: oggm.core.flowline: (RGI60-06.00472) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:02: oggm.core.flowline: (RGI60-06.00472) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:03: oggm.core.flowline: (RGI60-06.00473) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:03: oggm.core.flowline: (RGI60-06.00473) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:03: oggm.core.flowline: (RGI60-06.00474) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:03: oggm.core.flowline: (RGI60-06.00474) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:04: oggm.core.flowline: (RGI60-06.00475) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:04: oggm.core.flowline: (RGI60-06.00475) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:05: oggm.core.flowline: (RGI60-06.00476) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:05: oggm.core.flowline: (RGI60-06.00476) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:05: oggm.core.flowline: (RGI60-06.00477) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:05: oggm.core.flowline: (RGI60-06.00477) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:06: oggm.core.flowline: (RGI60-06.00478) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:06: oggm.core.flowline: (RGI60-06.00478) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:06: oggm.core.flowline: (RGI60-06.00479) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:06: oggm.core.flowline: (RGI60-06.00479) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:07: oggm.core.flowline: (RGI60-06.00480) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:07: oggm.core.flowline: (RGI60-06.00480) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:07: oggm.core.flowline: (RGI60-06.00481) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:07: oggm.core.flowline: (RGI60-06.00481) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:08: oggm.core.flowline: (RGI60-06.00482) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:08: oggm.core.flowline: (RGI60-06.00482) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:08: oggm.core.flowline: (RGI60-06.00483) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:08: oggm.core.flowline: (RGI60-06.00483) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:09: oggm.core.flowline: (RGI60-06.00556) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:09: oggm.core.flowline: (RGI60-06.00556) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:09: oggm.core.flowline: (RGI60-06.00557) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:09: oggm.core.flowline: (RGI60-06.00557) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:10: oggm.core.flowline: (RGI60-06.00558) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:10: oggm.core.flowline: (RGI60-06.00558) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:10: oggm.core.flowline: (RGI60-06.00559) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:10: oggm.core.flowline: (RGI60-06.00559) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:10: oggm.core.flowline: (RGI60-06.00560) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:10: oggm.core.flowline: (RGI60-06.00560) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:11: oggm.core.flowline: (RGI60-06.00561) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:11: oggm.core.flowline: (RGI60-06.00561) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:11: oggm.core.flowline: (RGI60-06.00562) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:11: oggm.core.flowline: (RGI60-06.00562) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:12: oggm.core.flowline: (RGI60-06.00563) run_from_climate_data_spinup_historical_monthly
# 2025-01-29 14:11:12: oggm.core.flowline: (RGI60-06.00563) flowline_model_run_spinup_historical_monthly
# 2025-01-29 14:11:12: oggm.utils: Applying global task compile_run_output on 118 glaciers
# 2025-01-29 14:11:12: oggm.utils: Applying compile_run_output on 118 gdirs.

# %% [markdown]
# ## calculate modelled elevation change

# %%
volume_total = ds_monthly.sum(dim='rgi_id').volume

# it is a bit unclear which basline was used by the observation
# from the meta_data: "average of the first 5 months (all data pre-2011)"
baseline_volume = np.mean(volume_total.sel(time=slice(2011, 2011.5)))

# divide by RGI area, which is the same area as used by the creation of the observation
rgi_area = 0
for gdir in gdirs:
    rgi_area += gdir.rgi_area_m2

# finally the calculation of the modelled elevation change
model_elev = (volume_total - baseline_volume) / rgi_area

# %% [markdown]
# ## Load observations of elevation change

# %%
df_obs_elev = pd.read_csv('/home/www/dtcg/test_files/case_study_regions/iceland/averaged_grid.csv', index_col=1)
df_obs_elev.index = pd.to_datetime(df_obs_elev.index)
df_obs_elev = df_obs_elev['changes_t0']  # only keep average which is used for comparision

# %% [markdown]
# ## plot elevation change observed vs. modelled

# %%
fig, ax = plt.subplots(1, 1)

df_obs_elev.plot(ax=ax, label='Observations (CryoSat-2)')

years, months = utils.floatyear_to_date(ds_monthly.time)
ax.plot(pd.to_datetime({'year': years, 'month': months, 'day': 1}),
        model_elev,
        label='DTCG')

ax.set_ylabel('Cumulative monthly change [m]')
ax.legend()
ax.grid('on')
ax.set_ylim([None, 3])
ax.set_title('Vatnajökull elevation change')
# Out:
# Text(0.5, 1.0, 'Vatnajökull elevation change')

# %% [markdown]
# # WGMS comparison

# %% [markdown]
# ## load WGMS data

# %%
fp_wgms = '/home/www/dtcg/test_files/case_study_regions/iceland/WGMS_MB-DTC-Glaciers.csv'
wgms_data = pd.read_csv(fp_wgms)

# %% [markdown]
# ## help function to access WGMS data

# %%
# conversions between wgms ids and rgi ids
fp_wgms_ids_conversion = '/home/www/dtcg/test_files/case_study_regions/iceland/glacier_id_lut.csv'
df_wgms_ids = pd.read_csv(fp_wgms_ids_conversion)

def get_wgms_from_rgi(rgi_id):
    if rgi_id in df_wgms_ids['RGI60_ID'].values:
        return df_wgms_ids[df_wgms_ids['RGI60_ID'] == rgi_id]['WGMS_ID'].item()
    else:
        return None

def get_rgi_from_wgms(wgms_id):
    if wgms_id in df_wgms_ids['WGMS_ID'].values:
        return df_wgms_ids[df_wgms_ids['WGMS_ID'] == wgms_id]['RGI60_ID'].item()
    else:
        return None

# %%
def get_wgms_mb_observation(rgi_id):
    '''
    Returns (mb_DataFrame, Glacier name)
    '''
    wgms_id = get_wgms_from_rgi(rgi_id)
    
    # only not None if this glacier is a WGMS glacier
    if wgms_id:
        # check if we have some data
        if wgms_id in wgms_data['glacier_id'].values:
            wgms_glacier_data = wgms_data[wgms_data['glacier_id'] == wgms_id]
            df_wgms_glacier_data = pd.DataFrame(
                {'annual_balance': wgms_glacier_data['annual_balance'].values},
                # ignoring hydro dates for now, as it is also what the model does
                index=pd.to_datetime(wgms_glacier_data['year'].values.astype(str)),
            )
            return df_wgms_glacier_data, wgms_glacier_data['glacier_id.short_name'].values[0]

# %% [markdown]
# # open modelled data

# %%
ds_annual = utils.compile_run_output(gdirs, input_filesuffix='_spinup_historical')
# Out:
# 2025-01-29 15:05:45: oggm.utils: Applying global task compile_run_output on 118 glaciers
# 2025-01-29 15:05:45: oggm.utils: Applying compile_run_output on 118 gdirs.

# %% [markdown]
# ## function for calculating modelled mb

# %%
def get_smb(ds, rgi_id):
    volume = ds.loc[{'rgi_id': rgi_id}].volume.values
    area = ds.loc[{'rgi_id': rgi_id}].area.values
    smb = (volume[1:] - volume[:-1]) / area[1:] * cfg.PARAMS['ice_density'] / 1000
    return smb

# %% [markdown]
# ## Plot WGMS and modelled mb for all available glaciers

# %%
for gdir in gdirs:
    wgms_mb = get_wgms_mb_observation(gdir.rgi_id)

    if wgms_mb is not None:
        fig, ax = plt.subplots(1, 1)

        # add modelled smb
        ax.plot(pd.to_datetime({'year': ds_annual.time[:-1], 'month': 1, 'day': 1}),
                get_smb(ds_annual, gdir.rgi_id),
                '.-',
                label='DTCG',
               )
        
        # add observation
        wgms_mb[0]['annual_balance'].plot(ax=ax, marker='.',
                                          label='Observation (WGMS)')
        
        ax.set_title(f'{gdir.rgi_id}, {wgms_mb[1]}')
        ax.legend()
        ax.grid('on')
        plt.show()
